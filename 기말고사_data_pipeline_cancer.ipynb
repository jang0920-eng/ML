# %% [markdown]
# ---
# ## 🎁 가산점
#
# ### A. 데이터의 다양성
# - NTP ICE 내 다양한 데이터셋 모두 활용 가능. (https://ice.ntp.niehs.nih.gov/DATASETDESCRIPTION)
# ### B. Feature(descriptor)의 다양성
# - rdkit, VEGA, 등
# ### 💬 추가 설명 (자유 기술)

# %% [markdown]
# # 기말고사 Template 1 — Data Pipeline
#
# **이름:** __장다예__ &nbsp; **학번:** ____20251281____ &nbsp;
#
# ---
#
# ## 📋 채점 기준 (총 50점)
#
# | 항목 | 배점 | 채점 포인트 |
# |---|---|---|
# | **1. 데이터 분포 파악 및 전처리** | 15점 | 모델 개발 전, 중복 화합물 체크, smiles 코드 정리 등 모델 개발 전 확인해야 할 사항들을 확인. |
# | **2. Descriptor 계산** | 15점 | 모델 개발에 사용할 descriptor의 다양성 |
# | **3. 데이터 시각화 자료** | 15점 | 구조 분포, 라벨 비율 등 데이터 현황을 시각화한 자료 |
# | **4. 코드 가독성 & 주석** | 5점 | 변수의 의미와 코드의 간결성을 평가. |
#
# #### A. 데이터 소스의 다양성
# - NTP ICE에서 구할 수 있는 다양한 데이터
# - NTP ICE 외 추가 데이터 확보
#
# ## 📁 입력 / 출력 예시
# - **입력**: `skin_irritation.xlsx` (NTP ICE) + (선택) 외부 데이터
# - **출력**: `final_dataset_descriptors.csv`  (Chemical_Name, SMILES, label, 2D descriptor [+ fingerprint 등])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. cancer.xlsx의 Data 시트 불러오기
df = pd.read_excel('cancer.xlsx', sheet_name='Data')
df
# Out:
#          Record_ID Data_Type Formulation_ID  \
# 0      cancer_4298   In Vivo            NaN
# 1      cancer_4297   In Vivo            NaN
# 2      cancer_3383   In Vivo            NaN
# 3      cancer_3383   In Vivo            NaN
# 4      cancer_3382   In Vivo            NaN
# ...            ...       ...            ...
# 10346  cancer_4524       WOE            NaN
# 10347  cancer_1567       WOE            NaN
# 10348  cancer_1568       WOE            NaN
# 10349  cancer_2718       WOE            NaN
# 10350  cancer_6891       WOE            NaN
#
#                                         Formulation_Name  \
# 0                 Valeriana officinalis L., root extract
# 1                 Valeriana officinalis L., root extract
# 2                                             Acronycine
# 3                                             Acronycine
# 4                                             Acronycine
# ...                                                  ...
# 10346                 Aminocyclopyrachlor potassium salt
# 10347                                  1,6-Dinitropyrene
# 10348                                  1,6-Dinitropyrene
# 10349                                     Momfluorothrin
# 10350  (4-Methyl-7-oxabicyclo[4.1.0]heptan-3-yl)methy...
#
#                                            Chemical_Name        CASRN  \
# 0                 Valeriana officinalis L., root extract    8057-49-6
# 1                 Valeriana officinalis L., root extract    8057-49-6
# 2                                             Acronycine    7008-42-6
# 3                                             Acronycine    7008-42-6
# 4                                             Acronycine    7008-42-6
# ...                                                  ...          ...
# 10346                 Aminocyclopyrachlor potassium salt  858956-35-1
# 10347                                  1,6-Dinitropyrene   42397-64-8
# 10348                                  1,6-Dinitropyrene   42397-64-8
# 10349                                     Momfluorothrin  609346-29-4
# 10350  (4-Methyl-7-oxabicyclo[4.1.0]heptan-3-yl)methy...     141-37-7
#
#                 DTXSID  Percent_Active_Ingredient   Mixture Species  ...  \
# 0      DTXSID001017359                        NaN  Chemical   Mouse  ...
# 1      DTXSID001017359                        NaN  Chemical   Mouse  ...
# 2        DTXSID0020026                        NaN  Chemical     Rat  ...
# 3        DTXSID0020026                        NaN  Chemical     Rat  ...
# 4        DTXSID0020026                        NaN  Chemical   Mouse  ...
# ...                ...                        ...       ...     ...  ...
# 10346   DTXSID90872814                        NaN  Chemical     NaN  ...
# 10347   DTXSID90872819                        NaN  Chemical     NaN  ...
# 10348   DTXSID90872819                        NaN  Chemical     NaN  ...
# 10349   DTXSID90897320                        NaN  Chemical     NaN  ...
# 10350   DTXSID90930968                        NaN  Chemical     NaN  ...
#
#                                          Endpoint  \
# 0                                    Micronucleus
# 1                                    Micronucleus
# 2                                        Top dose
# 3      Level of evidence of carcinogenic activity
# 4                                        Top dose
# ...                                           ...
# 10346                       Cancer classification
# 10347                                  IARC group
# 10348                              Listing status
# 10349                       Cancer classification
# 10350                                  IARC group
#
#                                       Response Response_Unit  \
# 0                              Weakly Positive      Unitless
# 1                                     Negative      Unitless
# 2                                           15     mg/kg/day
# 3                               Clear evidence      Unitless
# 4                                           25     mg/kg/day
# ...                                        ...           ...
# 10346  Not likely to be carcinogenic to humans      Unitless
# 10347                                       2B      Unitless
# 10348                                     RAHC      Unitless
# 10349  Not likely to be carcinogenic to humans      Unitless
# 10350                                        3      Unitless
#
#                                                Reference  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 TR-049
# 3                                                 TR-049
# 4                                                 TR-049
# ...                                                  ...
# 10346  U.S. EPA Office of Pesticide Programs, Chemica...
# 10347                                                NaN
# 10348                                                NaN
# 10349  U.S. EPA Office of Pesticide Programs, Chemica...
# 10350                                                NaN
#
#                                                      URL  \
# 0      https://cebs.niehs.nih.gov/cebs/test_article/8...
# 1      https://cebs.niehs.nih.gov/cebs/test_article/8...
# 2      https://ntp.niehs.nih.gov/publications/reports...
# 3      https://ntp.niehs.nih.gov/publications/reports...
# 4      https://ntp.niehs.nih.gov/publications/reports...
# ...                                                  ...
# 10346                                                NaN
# 10347  http://publications.iarc.fr/64; http://publica...
# 10348  https://ntp.niehs.nih.gov/ntp/roc/content/prof...
# 10349                                                NaN
# 10350  http://publications.iarc.fr/29; http://publica...
#
#                                                   SMILES  \
# 0                                                    NaN
# 1                                                    NaN
# 2      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 3      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 4      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# ...                                                  ...
# 10346              [K+].NC1=NC(=NC(C([O-])=O)=C1Cl)C1CC1
# 10347  [O-][N+](=O)C1=CC=C2C=CC3=C(C=CC4=CC=C1C2=C34)...
# 10348  [O-][N+](=O)C1=CC=C2C=CC3=C(C=CC4=CC=C1C2=C34)...
# 10349  COCC1=C(F)C(F)=C(COC(=O)C2C(C=C(C)C#N)C2(C)C)C...
# 10350                    CC1CC2OC2CC1COC(=O)C1CC2OC2CC1C
#
#                                           Preferred_Name  \
# 0                 Valeriana officinalis L., root extract
# 1                 Valeriana officinalis L., root extract
# 2                                             Acronycine
# 3                                             Acronycine
# 4                                             Acronycine
# ...                                                  ...
# 10346                 Aminocyclopyrachlor potassium salt
# 10347                                  1,6-Dinitropyrene
# 10348                                  1,6-Dinitropyrene
# 10349                                     Momfluorothrin
# 10350  (4-Methyl-7-oxabicyclo[4.1.0]heptan-3-yl)methy...
#
#                                                 Synonyms  \
# 0      8057-49-6|Valeriana officinalis L., root extra...
# 1      8057-49-6|Valeriana officinalis L., root extra...
# 2      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 3      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 4      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# ...                                                  ...
# 10346  858956-35-1|Aminocyclopyrachlor potassium salt...
# 10347  42397-64-8|1,6-Dinitropyrene|Pyrene, 1, 6- din...
# 10348  42397-64-8|1,6-Dinitropyrene|Pyrene, 1, 6- din...
# 10349  609346-29-4|Momfluorothrin|4-Methoxymethyl-2,3...
# 10350  141-37-7|(4-Methyl-7-oxabicyclo[4.1.0]heptan-3...
#
#                                              URL_CompTox  \
# 0      https://comptox.epa.gov/dashboard/chemical/det...
# 1      https://comptox.epa.gov/dashboard/chemical/det...
# 2      https://comptox.epa.gov/dashboard/chemical/det...
# 3      https://comptox.epa.gov/dashboard/chemical/det...
# 4      https://comptox.epa.gov/dashboard/chemical/det...
# ...                                                  ...
# 10346  https://comptox.epa.gov/dashboard/chemical/det...
# 10347  https://comptox.epa.gov/dashboard/chemical/det...
# 10348  https://comptox.epa.gov/dashboard/chemical/det...
# 10349  https://comptox.epa.gov/dashboard/chemical/det...
# 10350  https://comptox.epa.gov/dashboard/chemical/det...
#
#                                                 URL_CEBS
# 0      https://doi.org/10.22427/NTP-DATA-DTXSID001017359
# 1      https://doi.org/10.22427/NTP-DATA-DTXSID001017359
# 2        https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# 3        https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# 4        https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# ...                                                  ...
# 10346                                                NaN
# 10347                                                NaN
# 10348                                                NaN
# 10349                                                NaN
# 10350                                                NaN
#
# [10351 rows x 28 columns]

# %%
# 데이터 내 존재하는 종(Species)의 분포 확인
df['Species'].value_counts()
# Out:
# Species
# Mouse      3286
# Rat        2905
# Hamster      20
# Name: count, dtype: int64

# %%
# 2. 마우스(Mouse) 실험 결과이면서 단일 화학물질(Chemical)만 선택하여 필터링
df_m = df[(df['Species'] == 'Mouse') & (df['Mixture'] == 'Chemical')].copy()
df_m
# Out:
#          Record_ID Data_Type Formulation_ID  \
# 0      cancer_4298   In Vivo            NaN
# 1      cancer_4297   In Vivo            NaN
# 4      cancer_3382   In Vivo            NaN
# 5      cancer_3382   In Vivo            NaN
# 6      cancer_3381   In Vivo            NaN
# ...            ...       ...            ...
# 10302  cancer_3032   In Vivo            NaN
# 10303  cancer_7008   In Vivo            NaN
# 10304  cancer_7009   In Vivo            NaN
# 10308   cancer_483   In Vivo            NaN
# 10309   cancer_482   In Vivo            NaN
#
#                              Formulation_Name  \
# 0      Valeriana officinalis L., root extract
# 1      Valeriana officinalis L., root extract
# 4                                  Acronycine
# 5                                  Acronycine
# 6                                  Acronycine
# ...                                       ...
# 10302                    Allyl Glycidyl Ether
# 10303                               Tenofovir
# 10304                               Tenofovir
# 10308                  N-Methylacetoacetamide
# 10309                  N-Methylacetoacetamide
#
#                                 Chemical_Name        CASRN           DTXSID  \
# 0      Valeriana officinalis L., root extract    8057-49-6  DTXSID001017359
# 1      Valeriana officinalis L., root extract    8057-49-6  DTXSID001017359
# 4                                  Acronycine    7008-42-6    DTXSID0020026
# 5                                  Acronycine    7008-42-6    DTXSID0020026
# 6                                  Acronycine    7008-42-6    DTXSID0020026
# ...                                       ...          ...              ...
# 10302                    Allyl glycidyl ether     106-92-3    DTXSID9039232
# 10303                               Tenofovir  147127-20-6    DTXSID9040132
# 10304                               Tenofovir  147127-20-6    DTXSID9040132
# 10308                  N-Methylacetoacetamide   20306-75-6    DTXSID9040138
# 10309                  N-Methylacetoacetamide   20306-75-6    DTXSID9040138
#
#        Percent_Active_Ingredient   Mixture Species  ...  \
# 0                            NaN  Chemical   Mouse  ...
# 1                            NaN  Chemical   Mouse  ...
# 4                            NaN  Chemical   Mouse  ...
# 5                            NaN  Chemical   Mouse  ...
# 6                            NaN  Chemical   Mouse  ...
# ...                          ...       ...     ...  ...
# 10302                        NaN  Chemical   Mouse  ...
# 10303                        NaN  Chemical   Mouse  ...
# 10304                        NaN  Chemical   Mouse  ...
# 10308                        NaN  Chemical   Mouse  ...
# 10309                        NaN  Chemical   Mouse  ...
#
#                                          Endpoint               Response  \
# 0                                    Micronucleus        Weakly Positive
# 1                                    Micronucleus               Negative
# 4                                        Top dose                     25
# 5      Level of evidence of carcinogenic activity  Inadequate experiment
# 6                                        Top dose                     25
# ...                                           ...                    ...
# 10302                                    Top dose                     10
# 10303                                Micronucleus               Negative
# 10304                                Micronucleus               Positive
# 10308                                 Comet assay               Negative
# 10309                                Micronucleus               Negative
#
#       Response_Unit Reference  \
# 0          Unitless       NaN
# 1          Unitless       NaN
# 4         mg/kg/day    TR-049
# 5          Unitless    TR-049
# 6         mg/kg/day    TR-049
# ...             ...       ...
# 10302           ppm    TR-376
# 10303      Unitless       NaN
# 10304      Unitless       NaN
# 10308      Unitless       NaN
# 10309      Unitless       NaN
#
#                                                      URL  \
# 0      https://cebs.niehs.nih.gov/cebs/test_article/8...
# 1      https://cebs.niehs.nih.gov/cebs/test_article/8...
# 4      https://ntp.niehs.nih.gov/publications/reports...
# 5      https://ntp.niehs.nih.gov/publications/reports...
# 6      https://ntp.niehs.nih.gov/publications/reports...
# ...                                                  ...
# 10302  https://ntp.niehs.nih.gov/publications/reports...
# 10303  https://cebs.niehs.nih.gov/cebs/test_article/1...
# 10304  https://cebs.niehs.nih.gov/cebs/test_article/1...
# 10308  https://cebs.niehs.nih.gov/cebs/test_article/2...
# 10309  https://cebs.niehs.nih.gov/cebs/test_article/2...
#
#                                                   SMILES  \
# 0                                                    NaN
# 1                                                    NaN
# 4      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 5      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 6      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# ...                                                  ...
# 10302                                        C=CCOCC1CO1
# 10303             C[C@H](CN1C=NC2=C1N=CN=C2N)OCP(O)(O)=O
# 10304             C[C@H](CN1C=NC2=C1N=CN=C2N)OCP(O)(O)=O
# 10308                                     CNC(=O)CC(C)=O
# 10309                                     CNC(=O)CC(C)=O
#
#                                Preferred_Name  \
# 0      Valeriana officinalis L., root extract
# 1      Valeriana officinalis L., root extract
# 4                                  Acronycine
# 5                                  Acronycine
# 6                                  Acronycine
# ...                                       ...
# 10302                    Allyl glycidyl ether
# 10303                               Tenofovir
# 10304                               Tenofovir
# 10308                  N-Methylacetoacetamide
# 10309                  N-Methylacetoacetamide
#
#                                                 Synonyms  \
# 0      8057-49-6|Valeriana officinalis L., root extra...
# 1      8057-49-6|Valeriana officinalis L., root extra...
# 4      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 5      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 6      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# ...                                                  ...
# 10302  106-92-3|Allyl glycidyl ether|(.+-.)-Allyl gly...
# 10303  147127-20-6|Tenofovir|(((1R)-2-(6-Amino-9H-pur...
# 10304  147127-20-6|Tenofovir|(((1R)-2-(6-Amino-9H-pur...
# 10308  20306-75-6|N-Methylacetoacetamide|Acetoacet-mo...
# 10309  20306-75-6|N-Methylacetoacetamide|Acetoacet-mo...
#
#                                              URL_CompTox  \
# 0      https://comptox.epa.gov/dashboard/chemical/det...
# 1      https://comptox.epa.gov/dashboard/chemical/det...
# 4      https://comptox.epa.gov/dashboard/chemical/det...
# 5      https://comptox.epa.gov/dashboard/chemical/det...
# 6      https://comptox.epa.gov/dashboard/chemical/det...
# ...                                                  ...
# 10302  https://comptox.epa.gov/dashboard/chemical/det...
# 10303  https://comptox.epa.gov/dashboard/chemical/det...
# 10304  https://comptox.epa.gov/dashboard/chemical/det...
# 10308  https://comptox.epa.gov/dashboard/chemical/det...
# 10309  https://comptox.epa.gov/dashboard/chemical/det...
#
#                                                 URL_CEBS
# 0      https://doi.org/10.22427/NTP-DATA-DTXSID001017359
# 1      https://doi.org/10.22427/NTP-DATA-DTXSID001017359
# 4        https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# 5        https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# 6        https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# ...                                                  ...
# 10302    https://doi.org/10.22427/NTP-DATA-DTXSID9039232
# 10303    https://doi.org/10.22427/NTP-DATA-DTXSID9040132
# 10304    https://doi.org/10.22427/NTP-DATA-DTXSID9040132
# 10308    https://doi.org/10.22427/NTP-DATA-DTXSID9040138
# 10309    https://doi.org/10.22427/NTP-DATA-DTXSID9040138
#
# [3156 rows x 28 columns]

# %%
# 마우스 데이터 내에 존재하는 엔드포인트(Endpoint) 종류 및 빈도 확인
df_m['Endpoint'].value_counts()
# Out:
# Endpoint
# Top dose                                      1100
# Level of evidence of carcinogenic activity    1098
# Micronucleus                                   612
# POLY-3 lowest dose                             321
# Comet assay                                     25
# Name: count, dtype: int64

# %%
# 3. 발암성 평가 결과에 해당하는 'Level of evidence of carcinogenic activity'를 가진 데이터 추출
df_evi = df_m[df_m['Endpoint'] == 'Level of evidence of carcinogenic activity'].copy()

# 머신러닝 학습에 노이즈를 유발할 수 있는 불확실한 결과(Equivocal, Inadequate, Not tested 등) 제거
valid_responses = ['Clear evidence', 'Some evidence', 'No evidence']
df_evi = df_evi[df_evi['Response'].isin(valid_responses)].copy()
df_evi.shape
# Out:
# (897, 28)

# %%
# 필터링된 최종 발암성 응답 값들의 분포 확인
df_evi['Response'].value_counts()
# Out:
# Response
# No evidence       516
# Clear evidence    320
# Some evidence      61
# Name: count, dtype: int64

# %%
# 응답(Response) 값 분포 시각화
import matplotlib.pyplot as plt
evi_value = df_evi['Response'].value_counts()
plt.bar(evi_value.index, evi_value)
plt.xticks(rotation=45)
plt.title('Distribution of Carcinogenicity Response (Mouse)')
plt.show()

# %%
# 데이터 칼럼 확인
df_evi.columns
# Out:
# Index(['Record_ID', 'Data_Type', 'Formulation_ID', 'Formulation_Name',
#        'Chemical_Name', 'CASRN', 'DTXSID', 'Percent_Active_Ingredient',
#        'Mixture', 'Species', 'Sex', 'Strain', 'Route', 'Level_of_Evidence',
#        'Tissue', 'Location', 'Lesion', 'Assay', 'Endpoint', 'Response',
#        'Response_Unit', 'Reference', 'URL', 'SMILES', 'Preferred_Name',
#        'Synonyms', 'URL_CompTox', 'URL_CEBS'],
#       dtype='str')

# %%
# 4. 타겟 변수 이진 라벨링 (Active/발암성 있음 = 1, Inactive/발암성 없음 = 0)
df_evi['label'] = 0
df_evi.loc[df_evi['Response'].isin(['Clear evidence', 'Some evidence']),'label'] = 1

df_evi['label'].value_counts()
# Out:
# label
# 0    516
# 1    381
# Name: count, dtype: int64

# %%
df_evi['Sex'].value_counts()
# Out:
# Sex
# Female    461
# Male      436
# Name: count, dtype: int64

# %%
df_evi['Sex'] = df_evi['Sex'].map({'Male': 1,'Female': 0})
df_evi['Sex'].value_counts()
# Out:
# Sex
# 0    461
# 1    436
# Name: count, dtype: int64

# %%
# 데이터 칼럼 확인
df_evi.columns
# Out:
# Index(['Record_ID', 'Data_Type', 'Formulation_ID', 'Formulation_Name',
#        'Chemical_Name', 'CASRN', 'DTXSID', 'Percent_Active_Ingredient',
#        'Mixture', 'Species', 'Sex', 'Strain', 'Route', 'Level_of_Evidence',
#        'Tissue', 'Location', 'Lesion', 'Assay', 'Endpoint', 'Response',
#        'Response_Unit', 'Reference', 'URL', 'SMILES', 'Preferred_Name',
#        'Synonyms', 'URL_CompTox', 'URL_CEBS'],
#       dtype='str')

# %%
# 화합물 이름 리스트 상위 10개 확인
df_total['Chemical_Name'].to_list()[:10]
# Out:
# ['Benzyl acetate',
#  'Benzyl acetate',
#  'Benzyl acetate',
#  'Benzyl acetate',
#  '4-Chloro-1,3-diaminobenzene',
#  '4-Chloro-1,3-diaminobenzene',
#  '2-Chloro-1,4-diaminobenzene sulfate (1:1)',
#  '2-Chloro-1,4-diaminobenzene sulfate (1:1)',
#  '3-Chloro-4-methylaniline',
#  '3-Chloro-4-methylaniline']
